# %% [markdown]
# <a href="https://colab.research.google.com/github/lnwprameza007/pythion_dataviz2024/blob/main/Data_Viz_2024_Exam_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
crime_rep = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/crime_scene_report.csv')
crime_rep
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
dri_li = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/drivers_license.csv')
dri_li
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
event = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/facebook_event_checkin.csv')
event
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
check_in = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/get_fit_now_check_in.csv')
check_in
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
member = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/get_fit_now_member.csv')
member
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
income = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/income.csv')
income
# Out:
#             ssn  annual_income
# 0     100009868          52200
# 1     100169584          64500
# 2     100300433          74400
# 3     100355733          35900
# 4     100366269          73000
# ...         ...            ...
# 7509  999679296          54400
# 7510  999762859          77000
# 7511  999824984          82000
# 7512  999910617          82600
# 7513  999942603          11500
#
# [7514 rows x 2 columns]

# %%
interview = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/interview.csv')
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
person = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/person.csv')
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %% [markdown]
# ##Personal data

# %%
person_data = person.join(dri_li.set_index('id'), on='license_id')
person_data
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn   age  height eye_color hair_color  \
# 0            Bankhall Ave  747714076  46.0    59.0     black      green
# 1           Gustavus Blvd  477972044  54.0    74.0     black      white
# ...

# %% [markdown]
# ##สืบหาฆาตรกร ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City

# %%
crime_rep
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
case = crime_rep[crime_rep['city'] == 'SQL City']
case
# Out:
#           date     type                                        description  \
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# 7     20170712    theft  A lone hunter stalks the night, firing arrows ...
# 8     20170820    arson  Wield the Hammer of Sol with honor, Titan, it ...
# 9     20171110  robbery  The Gjallarhorn shoulder-mounted rocket system...
# 10    20180103  bribery  Apparently, Cayde thought it necessary to expo...
# 11    20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 12    20180115  assault                                   Report Not Found
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#           city
# 3     SQL City
# 4     SQL City
# 7     SQL City
# 8     SQL City
# 9     SQL City
# 10    SQL City
# 11    SQL City
# 12    SQL City
# 1227  SQL City

# %% [markdown]
# Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".

# %%
wit1 = person_data[person_data['address_street_name'] == 'Northwestern Dr']
wit1
# Out:
#          id                  name  license_id  address_number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %%
wit2 = person_data[person_data['address_street_name'] == 'Franklin Ave']
wit2
# Out:
#          id                 name  license_id  address_number  \
# 235   12207       Wilmer Wolever      509484             139
# 665   16371       Annabel Miller      490173             103
# 807   17683        Johnnie Schee      968887            1277
# 936   18651        Carleen Etoll      356746              22
# 1377  22636       Zachary Ybarbo      768359             785
# 1608  24737           Gema Nantz      273410            3968
# 2236  30654      Clarita Rickels      418084            2254
# 2427  32264       Shelby Dezeeuw      735415            1391
# 2584  33793         Amado Mattan      161915              99
# 2661  34592    Cordell Lindamood      592762            3657
# 2864  36328         Domenic Laun      971080            3809
# 2877  36400         Noe Pancoast      895755            3443
# 3009  37616     Katelyn Schwerin      430143             332
# 4086  46827         Bev Billiter      643591            2316
# ...

# %%
wit2[wit2['name'] == 'Annabel Miller']
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn   age  height eye_color hair_color  gender plate_number  \
# 665  318771143  35.0    65.0     green      brown  female       23AM98
#
#     car_make car_model
# 665   Toyota     Yaris

# %%
event_wit2 = event[event['person_id'] == 16371]
event_wit2
# Out:
#        person_id  event_id              event_name      date
# 20005      16371      4719  The Funky Grooves Tour  20180115

# %%
people_in_e = event[event['event_name'] == 'The Funky Grooves Tour']
people_in_e
# Out:
#        person_id  event_id              event_name      date
# 20004      14887      4719  The Funky Grooves Tour  20180115
# 20005      16371      4719  The Funky Grooves Tour  20180115
# 20009      67318      4719  The Funky Grooves Tour  20180115

# %%
wit11 = people_in_e.join(person_data.set_index('id'), on='person_id')
wit11
# Out:
#        person_id  event_id              event_name      date            name  \
# 20004      14887      4719  The Funky Grooves Tour  20180115  Morty Schapiro
# 20005      16371      4719  The Funky Grooves Tour  20180115  Annabel Miller
# 20009      67318      4719  The Funky Grooves Tour  20180115   Jeremy Bowers
#
#        license_id  address_number    address_street_name        ssn   age  \
# 20004      118009            4919        Northwestern Dr  111564949  64.0
# 20005      490173             103           Franklin Ave  318771143  35.0
# 20009      423327             530  Washington Pl, Apt 3A  871539279  30.0
#
#        height eye_color hair_color  gender plate_number       car_make  \
# 20004    84.0      blue      white    male       00NU00  Mercedes-Benz
# 20005    65.0     green      brown  female       23AM98         Toyota
# 20009    70.0     brown      brown    male       0H42W2      Chevrolet
#
#       car_model
# 20004   E-Class
# 20005     Yaris
# 20009  Spark LS

# %%
interview[interview['person_id'] == 14887]
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...

# %%
interview[interview['person_id'] == 16371]
# Out:
#       person_id                                         transcript
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
member[member['id'].str.startswith('48Z')][member['membership_status']=='gold']
# Out:
# <ipython-input-98-4682d3f7c908>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   member[member['id'].str.startswith('48Z')][member['membership_status']=='gold']
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
dv = dri_li[dri_li['plate_number'].str.contains('H42W')]
dv
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
person_data[person_data['name'] == 'Jeremy Bowers']
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn   age  height eye_color hair_color gender plate_number  \
# 6327  871539279  30.0    70.0     brown      brown   male       0H42W2
#
#        car_make car_model
# 6327  Chevrolet  Spark LS

# %%
# prompt: หาคนที่ check in วันที่ 20180109

check_in_list[check_in_list['check_in_date']==20180109]
# Out:
#         id  person_id               name  membership_start_date  \
# 9    X0643      15247     Shondra Ledlow               20170521
# 70   UK1F2      28073   Zackary Cabotage               20170818
# 96   XTE42      55662     Sarita Bartosh               20170524
# 103  1AE2H      10815   Adriane Pelligra               20170816
# 119  6LSTG      83186      Burton Grippe               20170214
# 147  7MWHJ      31523  Blossom Crescenzo               20180309
# 164  GE5Q8      92736      Carmen Dimick               20170618
# 181  48Z7A      28819       Joe Germuska               20160305
# 182  48Z55      67318      Jeremy Bowers               20160101
# 183  90081      16371     Annabel Miller               20160208
#
#     membership_status  check_in_date  check_in_time  check_out_time
# 9              silver       20180109            957            1164
# 70             silver       20180109            344             518
# ...

# %%
interview[interview['person_id'] == 28819]
# Out:
# Empty DataFrame
# Columns: [person_id, transcript]
# Index: []

# %%
interview[interview['person_id'] == 67318]
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %%
# prompt: person_data that woman has red hair carmodel tesla model s

per_sus = person_data[(person_data.gender == 'female') & (person_data.hair_color == 'red') & (person_data.car_make == 'Tesla') & (person_data.car_model == 'Model S')]
per_sus
# Out:
#          id              name  license_id  address_number address_street_name  \
# 7664  78881          Red Korb      918773             107         Camerata Dr
# 8977  90700     Regina George      291182             332           Maple Ave
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn   age  height eye_color hair_color  gender plate_number  \
# 7664  961388910  48.0    65.0     black        red  female       917UU3
# 8977  337169072  65.0    66.0      blue        red  female       08CM64
# 9985  987756388  68.0    66.0     green        red  female       500123
#
#      car_make car_model
# 7664    Tesla   Model S
# 8977    Tesla   Model S
# 9985    Tesla   Model S

# %%
per_sus.join(event.set_index('person_id'), on='id')
# Out:
#          id              name  license_id  address_number address_street_name  \
# 7664  78881          Red Korb      918773             107         Camerata Dr
# 8977  90700     Regina George      291182             332           Maple Ave
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn   age  height eye_color hair_color  gender plate_number  \
# 7664  961388910  48.0    65.0     black        red  female       917UU3
# 8977  337169072  65.0    66.0      blue        red  female       08CM64
# 9985  987756388  68.0    66.0     green        red  female       500123
# 9985  987756388  68.0    66.0     green        red  female       500123
# 9985  987756388  68.0    66.0     green        red  female       500123
#
# ...

# %%
interview[interview['person_id'] == 99716]
# Out:
# Empty DataFrame
# Columns: [person_id, transcript]
# Index: []

# %%
ic = person_data.join(income.set_index('ssn'), on='ssn')
ic
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn   age  height eye_color hair_color  \
# 0            Bankhall Ave  747714076  46.0    59.0     black      green
# 1           Gustavus Blvd  477972044  54.0    74.0     black      white
# ...

# %%
ic[ic['id'] == 67318]
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn   age  height eye_color hair_color gender plate_number  \
# 6327  871539279  30.0    70.0     brown      brown   male       0H42W2
#
#        car_make car_model  annual_income
# 6327  Chevrolet  Spark LS        10500.0

# %%
# prompt: แปลง event date เป็น strr

event['event_date'] = event['date'].astype(str)
event
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date event_date
# ...

# %%
# prompt: Miranda Priestly in SQL Symphony Concert 3 times in December 2017

event[(event.person_id == 99716)]
# Out:
#        person_id  event_id            event_name      date event_date
# 20006      99716      1143  SQL Symphony Concert  20171206   20171206
# 20007      99716      1143  SQL Symphony Concert  20171212   20171212
# 20008      99716      1143  SQL Symphony Concert  20171229   20171229

# %%
# prompt: หาคนที่ไป SQL Symphony Concert	วันที่ 20171206 20171212 20171229

ev = event[(event.event_name == 'SQL Symphony Concert') & (event.event_date.isin(['20171206','20171212','20171229']))]
ev
# Out:
#        person_id  event_id            event_name      date event_date
# 8395       92343      1143  SQL Symphony Concert  20171212   20171212
# 15896      69325      1143  SQL Symphony Concert  20171206   20171206
# 20006      99716      1143  SQL Symphony Concert  20171206   20171206
# 20007      99716      1143  SQL Symphony Concert  20171212   20171212
# 20008      99716      1143  SQL Symphony Concert  20171229   20171229
# 20010      67318      1143  SQL Symphony Concert  20171206   20171206

# %%
ev.join(person_data.set_index('id'), on='person_id')
# Out:
#        person_id  event_id            event_name      date event_date  \
# 8395       92343      1143  SQL Symphony Concert  20171212   20171212
# 15896      69325      1143  SQL Symphony Concert  20171206   20171206
# 20006      99716      1143  SQL Symphony Concert  20171206   20171206
# 20007      99716      1143  SQL Symphony Concert  20171212   20171212
# 20008      99716      1143  SQL Symphony Concert  20171229   20171229
# 20010      67318      1143  SQL Symphony Concert  20171206   20171206
#
#                    name  license_id  address_number    address_street_name  \
# 8395   Freida Betschart      575390            1255             Macoma Ave
# 15896       Tyson Ojard      142413            3187           Fletcher Way
# 20006  Miranda Priestly      202298            1883             Golden Ave
# 20007  Miranda Priestly      202298            1883             Golden Ave
# 20008  Miranda Priestly      202298            1883             Golden Ave
# ...

# %% [markdown]
# ## สรุป  ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City โดยมีลำดับเหตุการณ์ดังนี้
#
# วันที่ 6 ธันวาคม 2017 ณ SQL Symphony Concert Miranda Priestly ได้จ้าง Jeremy Bowers ให้ทำการฆาตกรรม เป็นจำนวนเงิน 10,500
#
# วันที่ 15 มกราคม 2018 ณ The Funky Grooves Tour Jeremy Bowers ได้ทำการฆาตกรรม แล้วหลบหนีด้วยรถ Chevrolet Spark LS ทะเบียน 0H42W2
#
# สรุปตามกฎหมายไทยได้ว่า Miranda Pristly กระทำความผิด ป.อาญา มาตรา 84 ผู้ใดก่อให้ผู้อื่นกระทำความผิดไม่ว่าด้วยการใช้ บังคับ ขู่เข็ญ จ้าง วานหรือยุยงส่งเสริม หรือด้วยวิธีอื่นใด ผู้นั้นเป็นผู้ใช้ให้กระทำความผิด
# โดยที่ Jeremy Bowers กระทำความผิด ป.อาญามาตรา 289 (4) การฆ่าผู้อื่นโดยไตร่ตรองไว้ก่อน
#
# ถ้าดูตามเหตุการณ์ Jeremy Bowers คือฆาตกร
# แต่ถ้าดูตามกฏหมายไทย  Miranda Priestly คือฆาตกร
